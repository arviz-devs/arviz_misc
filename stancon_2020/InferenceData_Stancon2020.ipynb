# %% [markdown]
# # ArviZ Stancon 2020
# We're gonna talk about some real cool stuff

# %% [markdown]
# ### Helpful links
# https://www.markroepke.me/posts/2019/05/23/creating-interactive-slideshows-in-jupyter.html
# https://www.markroepke.me/posts/2019/06/05/tips-for-slideshows-in-jupyter.html
# https://fedebarabas.github.io/blog/jupyter_slides/
# https://medium.com/@mjspeck/presenting-code-using-jupyter-notebook-slides-a8a3c3b59d67
# https://github.com/jupyterlab/jupyterlab/issues/5018
# https://towardsdatascience.com/7-essential-tips-for-writing-with-jupyter-notebook-60972a1a8901
# https://www.blog.pythonlibrary.org/2018/09/25/creating-presentations-with-jupyter-notebook/

# %% [markdown]
# # This is a subslide
# Let's see what it looks like

# %% [markdown]
# # This is a fragment
# Let's see what it looks like

# %% [markdown]
# # Presentation Start

# %% [markdown]
# # ArviZ and Inference Data
# Making the lives of Bayesians better
#
# ## Agenda
# * The Bayesian Workflow
# * Where ArviZ fits in
# * Where InferenceData fits in
# * Where the community fits
# * What doesn't quite fit in (yet)
# * Where you fit in

# %% [markdown]
# # Bayesian Workflow
# There's so many steps. PPLs only help out with a couple. ArviZ helps out with these ones. Lets add some colors and a legend so things are more obvious
# ![Bayesian Workflow](img/Bayesian_workflow.png)

# %% [markdown]
# # Many PPls, Same data, Same Visualization
# PPL choice may depend on syntax, sampler but steps outcome of MCMC sampler (chains and draws), as well as diagnostics and visualizations are largely the same
#
# *Turn this into a collage in a photo editor*
# ![Stan](https://raw.githubusercontent.com/stan-dev/logos/master/logo_tm.png)
# ![PyMC3](https://cdn.rawgit.com/pymc-devs/pymc3/master/docs/logos/svg/PyMC3_banner.svg)
# ![Turing](https://raw.githubusercontent.com/TuringLang/Turing.jl/master/docs/assets/turing-logo.svg)
#
# Other sources:
# * Turing: https://github.com/TuringLang/Turing.jl/tree/master/docs/assets
# * Pyro: https://github.com/pyro-ppl/artwork/tree/master/icon/color
# * TF: http://www.tensorflow.org/extras/tensorflow-brand-assets.zip

# %% [markdown]
# # So much data
# Dataframes with integrated indexing proved valuable for analysis. Bayesian data is high dimensional, but shares many of the challenges.

# %% [markdown]
# 5. We propose InferenceData Standard to share results (Show specification at high level here)

# %% [markdown]
# # Inference Data Overview
# ![PyMC3](https://arviz-devs.github.io/arviz/_images/InferenceDataStructure.png)

# %%
import arviz as az

# Change this to NetCDF local load so its obvious
InferenceData = az.load_arviz_data("non_centered_eight")
InferenceData
# Out:
# Inference data with groups:
# 	> posterior
# 	> posterior_predictive
# 	> sample_stats
# 	> prior
# 	> observed_data

# %% [markdown]
# # Inference Data already integrated with stan interfaces
# Insert picture or code here

# %% [markdown]
# # Organized data makes complex calculation easy
# Check out this loo plot that Oriol is going to add that is so easy cause the data is so organized

# %% [markdown]
# ## ArviZ and InferenceData benefits
# * Consistent language and PPL data representation
# * Portable and persistent in NetCDF format
# * Sharable datasets encourage reproducibility
# * Allows PPL designers to focus on PPL and not out of sampler diagnostics and plots
# *

# %% [markdown]
# ## Limitations
# * MCMC Specific
# * Doesn't make full workflow reproducible, just parts of it

# %% [markdown]
# ## Could use help!
# * Support for sparse data structures
# * Additional plots and diagnostics
# * Code, feedback, cool plots you made

# %% [markdown]
# ## Add InferenceData support to your package
# * InferenceData is a organization spec, don't need to use ArviZ or Python to implement to and from InferenceData in your library
#
# ![](img/ArviZ.R.png)

# %% [markdown]
# ## Helpful Links
# * Find some precomputed InferenceData objects here
# * ArviZ docs
# * ArviZ repo
